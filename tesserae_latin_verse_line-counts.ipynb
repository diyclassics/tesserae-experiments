# %%
# imports

import pandas as pd

from cltk.corpus.readers import get_corpus_reader
from cltk.tokenize.line import LineTokenizer

import pickle

# corpus / tools

corpus = get_corpus_reader(corpus_name = 'latin_text_tesserae', language = 'latin')
files = corpus.fileids()
modes = pickle.load(open('data/modes.p', 'rb'))
line_tokenizer = LineTokenizer('latin')

# %%
# Get line counts for all Tesserae files

data = []

docs = corpus.docs(files)
for i, doc in enumerate(docs):
    lines = line_tokenizer.tokenize(doc)
    file = files[i]
    file_ = file.replace('texts/','').replace('.tess','')
    author, work = file_.split('.')[0:2]
    part = file_.split('.')[-1]
    count = len(lines)
    data.append((file, author, work, part, count))

# %%
# Make dataframe of line counts 

df = pd.DataFrame(data, columns=['file', 'author', 'work', 'part', 'line count'])
df['part'] = df['part'].apply(lambda x: x if x.isnumeric() else '')
df['mode'] = df['file'].apply(lambda x: modes[x])
df.head()
# Out:
#                                          file    author            work part  \
# 0  texts/ammianus.rerum_gestarum.part.14.tess  ammianus  rerum_gestarum   14
# 1  texts/ammianus.rerum_gestarum.part.15.tess  ammianus  rerum_gestarum   15
# 2  texts/ammianus.rerum_gestarum.part.16.tess  ammianus  rerum_gestarum   16
# 3  texts/ammianus.rerum_gestarum.part.17.tess  ammianus  rerum_gestarum   17
# 4  texts/ammianus.rerum_gestarum.part.18.tess  ammianus  rerum_gestarum   18
#
#    line count   mode
# 0         181  prose
# 1         172  prose
# 2         191  prose
# 3         176  prose
# 4         113  prose

# %%
# Restrict data to verse

df_verse = df[df['mode'] == 'verse']
df_verse.head()
# Out:
#                                      file     author               work part  \
# 18     texts/anonymous.laudes_domini.tess  anonymous      laudes_domini
# 44   texts/ausonius.cupido_cruciatus.tess   ausonius   cupido_cruciatus
# 46       texts/ausonius.de_herediolo.tess   ausonius       de_herediolo
# 47  texts/ausonius.de_xii_caesaribus.tess   ausonius  de_xii_caesaribus
# 48    texts/ausonius.eclogarum_liber.tess   ausonius    eclogarum_liber
#
#     line count   mode
# 18         149  verse
# 44         103  verse
# 46          33  verse
# 47          29  verse
# 48         445  verse

# %%
# Group data by work

df_verse_work = df_verse.groupby(['author', 'work'])[['line count']].agg('sum')
df_verse_work
# Out:
#                                     line count
# author           work
# anonymous        laudes_domini             149
# ausonius         cupido_cruciatus          103
#                  de_herediolo               33
#                  de_xii_caesaribus          29
#                  eclogarum_liber           445
# ...                                        ...
# tibullus         elegies                  1929
# valerius_flaccus argonautica              5592
# vergil           aeneid                   9896
#                  eclogues                  828
#                  georgics                 2183
#
# [122 rows x 1 columns]

# %%
# Group data by verse author

df_verse_author = df_verse.groupby(['author'])[['line count']].agg('sum')
df_verse_author
# Out:
#                   line count
# author
# anonymous                149
# ausonius                4471
# catullus                2286
# claudian               10141
# corippus                4667
# dracontius              5973
# ennius                   680
# ennodius                1955
# horace                  7816
# italicus                1071
# juvenal                 3853
# juvencus                3182
# lucan                   8061
# lucretius               7425
# manilius                4293
# martial                 6399
# ovid                   34008
# paulus_diaconus         1714
# persius                  650
# plautus                21164
# polignac               19381
# priscian                2842
# propertius              3982
# prudentius              5339
# rutilius                 712
# seneca                 12033
# silius_italicus        12198
# statius                14751
# terence                 6188
# tibullus                1929
# valerius_flaccus        5592
# vergil                 12907

# %%
# Export reports

df_verse_work.to_csv('reports/verse_work_line-counts.csv')
df_verse_author.to_csv('reports/verse_author_line-counts.csv')
